# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasDhake/ColabNotebooks/blob/main/LAMA_Zero_Shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 30.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 77.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 35.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 67.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 41.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
#Download code
# !git clone https://github.com/HRL-Mike/PitVQA.git

#Download Dataset
# !mkdir /content/PitVQA/datasets
# %cd /content/PitVQA/datasets
# !gdown --id 1FoAEY_u0PTAlrscjEifi2om15A83wL78

# Unzipping the VQA EndoVis18 Dataset
# !unzip -q EndoVis-18-VQA.zip
# %cd /content/PitVQA
# Out:
# Cloning into 'PitVQA'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 401 (delta 74), reused 0 (delta 0), pack-reused 262 (from 1)
# Receiving objects: 100% (401/401), 14.44 MiB | 14.74 MiB/s, done.
# Resolving deltas: 100% (199/199), done.
# /content/PitVQA/datasets
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1FoAEY_u0PTAlrscjEifi2om15A83wL78
# From (redirected): https://drive.google.com/uc?id=1FoAEY_u0PTAlrscjEifi2om15A83wL78&confirm=t&uuid=b7957ed6-bcb7-4abb-a395-2ad5787d39d1
# To: /content/PitVQA/datasets/EndoVis-18-VQA.zip
# 100% 2.71G/2.71G [00:36<00:00, 74.4MB/s]
# /content/PitVQA

# %%
import os
import glob

from PIL import Image # Python Imaging Libary for image processing
from torch.utils.data import Dataset # Used to create custom datasets
import torchvision.transforms as transforms # Imports transomfrations to images
from torch.utils.data import DataLoader # helps to easily load batches of data from dataset
from pathlib import Path
from torchvision.transforms.functional import InterpolationMode # type of method used to resize images

class EndoVis18VQAGPTGen(Dataset):
    def __init__(self, seq, folder_head, folder_tail):
# seq = list of sequence numbers of identifiers, folder head and tail is the start and end of folder path
        self.transform = transforms.Compose([
            transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),  # input image size
            #transforms.ToTensor(),
        ])
# Resizing images to 224x224 using bicubic interpolation and they are made as tensors for the model
        # files, question and answers
        # Appens filenames to match the structure
        filenames = []
        for curr_seq in seq:
            filenames = filenames + glob.glob(folder_head + str(curr_seq) + folder_tail)
        self.vqas = []
        for file in filenames:
            file_data = open(file, "r")
            lines = [line.strip("\n") for line in file_data if line != "\n"]
            file_data.close()
            for line in lines:
                self.vqas.append([file, line])
        print('Total files: %d | Total question: %.d' % (len(filenames), len(self.vqas)))

        # List of predifined labels
        self.labels = ['kidney',
                'Idle', 'Grasping', 'Retraction', 'Tissue_Manipulation',
                'Tool_Manipulation', 'Cutting', 'Cauterization', 'Suction',
                'Looping', 'Suturing', 'Clipping', 'Staple', 'Ultrasound_Sensing',
                'left-top', 'right-top', 'left-bottom', 'right-bottom']

# Returns total number of samples in the dataset
    def __len__(self):
        return len(self.vqas)

# retrieves a specific dataset item by index idx
    def __getitem__(self, idx):
        qa_full_path = Path(self.vqas[idx][0])
        seq_path = qa_full_path.parents[2] # Gets grandparent directory two levels up of file path
        file_name = self.vqas[idx][0].split('/')[-1]  # / in linux and \\ in windows

        # img
        # Constructs path to the iamge file and joints the image with base name of the question file
        img_loc = os.path.join(seq_path, 'left_fr', file_name.split('_')[0] + '.png')
        raw_image = Image.open(img_loc).convert('RGB')
        img = self.transform(raw_image) # Applies transformation to the image (resizing and tensor conversion)

        # question and answer
        question, answer = self.vqas[idx][1].split('|') # splits qeustion and answer with |

        return img_loc, img, question, answer

# %%
system_message = """You are a Vision Language Model specialized in interpreting visual data from chart images.
Your task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.
The charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.
Focus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary."""

def format_data(sample):
    return [
        # {
        #     "role": "system",
        #     "content": [
        #         {
        #             "type": "text",
        #             "text": system_message
        #         }
        #     ],
        # },
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "image": sample[1],
                },
                {
                    "type": "text",
                    "text": sample[2],
                }
            ],
        },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[3]
                }
            ],
        },
    ]

# %%
class Args:
    def __init__(self):
        self.epochs = 20
        self.batch_size = 1

        self.random_seed = 42
        self.seq_length = 32
        self.lr = 0.00002

        self.vector_rank = [14, 14, 12, 12, 10, 10, 8, 8, 8, 8, 8, 8]
        self.lora_alpha = 32
        self.lora_dropout = 0.1


args = Args()
from torch.utils.data import DataLoader
val_seq = [1, 5, 16]

folder_head = '/content/PitVQA/datasets/EndoVis-18-VQA/seq_'
folder_tail = '/vqa/Sentence/*.txt'
PitVis_dataset = EndoVis18VQAGPTGen(val_seq, folder_head, folder_tail)
#PitVis_data = DataLoader(dataset=PitVis_dataset, batch_size=args.batch_size, shuffle=True)
PitVis_data = [format_data(sample) for sample in PitVis_dataset]
# Out:
# Total files: 447 | Total question: 3216

# %%
for idx, sample in enumerate(PitVis_data):
    print(f"Sample {idx}: {sample}")
    if idx == 0:  # Check only a few samples
        break

# for idx, sample in enumerate(PitVis_data):
#     print("Sample:", sample)
#     if idx == 0:
#         break

test_data = sample
# Out:
# Sample 0: [{'role': 'user', 'content': [{'type': 'image', 'image': <PIL.Image.Image image mode=RGB size=224x224 at 0x791246878E90>}, {'type': 'text', 'text': 'what organ is being operated?'}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'organ being operated is kidney'}]}]

# %%
import gc
import time
from torchvision.transforms import ToPILImage


def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )

    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[0].convert("RGB")
    image_inputs = sample[0]['content'][0]['image']
    #image_inputs = (sample[0].convert("RGB")).ToPILImage()
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
import torch
clear_memory()
# Out:
# GPU allocated memory: 0.00 GB
# GPU reserved memory: 0.00 GB

# %%
# !pip install -q evaluate

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained(model_id)
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )

# with torch.no_grad():
#     for idx, sample in enumerate(PitVis_data):
#         outputs = generate_text_from_sample(model, processor, sample)
#         print("Outputs:", outputs)
#         if idx == 0:  # Test one batch
#             break

all_pred = []
all_ans = []
model.eval()
with torch.no_grad():
    for sample in PitVis_data:
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/89.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-97370c91bff0> in <cell line: 0>()
#      39 with torch.no_grad():
#      40     for sample in PitVis_data:
# ---> 41         output = generate_text_from_sample(model, processor, sample)
#      42         ans = sample[1]['content'][0]['text']
#      43         all_pred.append(output)
#
# <ipython-input-9-0845c5873503> in generate_text_from_sample(model, processor, sample, max_new_tokens, device)
#      49
#      50     # Generate text with the model
# ---> 51     generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)
#      52
#      53     # Trim the generated ids to remove the input ids
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2046
#    2047             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2048             result = self._sample(
#    2049                 input_ids,
#    2050                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3006
#    3007             # forward pass to get next token
# -> 3008             outputs = self(**model_inputs, return_dict=True)
#    3009
#    3010             if synced_gpus and this_peer_finished:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, pixel_values, aspect_ratio_mask, aspect_ratio_ids, attention_mask, cross_attention_mask, cross_attention_states, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep)
#    2186             full_text_row_masked_out_mask = full_text_row_masked_out_mask[:, :, cache_position]
#    2187
# -> 2188         outputs = self.language_model(
#    2189             input_ids=input_ids,
#    2190             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, attention_mask, position_ids, cross_attention_states, cross_attention_mask, full_text_row_masked_out_mask, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep)
#    1927
#    1928         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1929         outputs = self.model(
#    1930             input_ids=input_ids,
#    1931             cross_attention_states=cross_attention_states,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, input_ids, attention_mask, position_ids, cross_attention_states, cross_attention_mask, full_text_row_masked_out_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1727                 )
#    1728             else:
# -> 1729                 layer_outputs = decoder_layer(
#    1730                     hidden_states,
#    1731                     cross_attention_states=cross_attention_states,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, hidden_states, cross_attention_states, cross_attention_mask, attention_mask, full_text_row_masked_out_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings)
#    1004         hidden_states = self.input_layernorm(hidden_states)
#    1005
# -> 1006         hidden_states, attn_weights, past_key_value = self.cross_attn(
#    1007             hidden_states=hidden_states,
#    1008             attention_mask=cross_attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.11/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in forward(self, hidden_states, cross_attention_states, past_key_value, attention_mask, output_attentions, use_cache, cache_position)
#     632             )
#     633
# --> 634         key_states = repeat_kv(key_states, self.num_key_value_groups)
#     635         value_states = repeat_kv(value_states, self.num_key_value_groups)
#     636
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mllama/modeling_mllama.py in repeat_kv(hidden_states, n_rep)
#     701
#     702 # Copied from transformers.models.llama.modeling_llama.repeat_kv
# --> 703 def repeat_kv(hidden_states: torch.Tensor, n_rep: int) -> torch.Tensor:
#     704     """
#     705     This is the equivalent of torch.repeat_interleave(x, dim=1, repeats=n_rep). The hidden states go from (batch,
#
# KeyboardInterrupt:

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: The organ being operated on is the heart.
# ans: organ being operated is kidney
# pred: The image shows a laparoscope and a suction/irrigation device being used to operate on an organ. The laparoscope is a long, thin tube with a light and camera on the end that allows the surgeon to see inside the body and perform surgical procedures. The suction/irrigation device is used to remove debris and fluids from the area being operated on.
# ans: the tools operating are prograsp forceps , monopolar curved scissors , suction
# pred: The ProGrasp forceps is a medical instrument used for grasping and manipulating tissue during surgical procedures. It is designed to provide a secure and atraumatic grip on delicate tissues, minimizing the risk of tissue damage or trauma.
#
# **Key Features:**
#
# * **Grasping Forceps**: The ProGrasp forceps features a pair of jaws that can be opened and closed to grasp and hold onto tissue.
# * **Atraumatic Design**: The jaws are designed to be atraumatic, meaning they do not cause damage to the tissue they grasp.
# * **Secure Grip**: The forceps provide a secure grip on the tissue, allowing for precise control and manipulation.
# * **Versatility**: The ProGrasp forceps can be used in various surgical procedures, including laparoscopic and open surgeries.
#
# **Importance in Surgery**: The ProGrasp forceps is an essential tool in many surgical specialties, including general surgery, gynecology, and urology. Its ability to provide a secure and atraumatic grip on delicate tissues makes it an invaluable asset in many surgical procedures.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors in the image is that they are being used to cut through a piece of tissue. The scissors are held by a hand, which is not visible in the image, and are positioned to cut through a piece of tissue that appears to be a part of the human body, possibly the abdominal wall or a tumor. The scissors are curved, suggesting that they are designed for precise cutting and dissection in tight spaces. The fact that the scissors are being used to cut through tissue suggests that they are being used in a surgical procedure, possibly to remove a tumor or perform a biopsy.
# ans: action done by monopolar curved scissors is cauterization
# pred: The state of suction is the process of removing fluid or gas from a system or container by creating a partial vacuum.
# ans: action done by suction is idle
# pred: The ProGrasp forceps are located in the abdominal cavity, as shown in the image.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the middle of the image, held by a hand with a white sleeve. The scissor tips are covered in a white plastic sheath and are being held by a gloved hand. The scissors are positioned in the middle of the image, with the tips pointing towards the bottom right corner. The hand holding the scissors is wearing a white sleeve, which is likely a surgical glove. The background of the image is a close-up view of a human body part, possibly the abdomen or chest, with visible blood vessels and organs. The image appears to be taken during a medical procedure, possibly surgery or an examination.
# ans: monopolar curved scissors is located at right-top
# pred: The suction is located in the lower right corner of the image, specifically in the abdominal cavity.
# ans: suction is located at right-top
# pred: The organ being operated on appears to be the heart, as indicated by the presence of a heart-lung machine and the surgical tools in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps and a suction irrigator, which are used to manipulate and remove tissue during the procedure.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors , suction
# pred: Bipolar forceps are in an open position, with the tips of the jaws separated.
# ans: action done by bipolar forceps is tissue manipulation
# pred: The ProGrasp forceps are in a state of being used for cardiac surgery.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is that it is being used in a surgical procedure, as indicated by its presence in the image. The scissors are likely being used to cut through tissue or other materials during the operation.
# ans: action done by monopolar curved scissors is cutting
# pred: The image depicts a heart with a mechanical pump and tubes attached to it, indicating that the heart is in a state of mechanical assistance or support. The presence of these devices suggests that the heart is not functioning properly on its own and needs external help to maintain proper blood flow and oxygenation. This could be due to various reasons such as heart failure, cardiomyopathy, or other cardiac conditions that impair the heart's ability to pump blood effectively.
#
# The mechanical pump is likely a ventricular assist device (VAD), which is a medical device that helps the heart pump blood throughout the body when it is unable to do so on its own. The tubes attached to the pump are probably connected to the heart and the rest of the circulatory system, allowing the device to pump blood into the body. The image suggests that the patient is undergoing mechanical circulatory support to help their heart function properly and improve their overall cardiac output and oxygenation.
#
# It's important to note that the image does not provide information about the specific condition of the patient or the reason for the mechanical support. However, it is clear that the heart is in a state of mechanical assistance, which is a common treatment for certain cardiac conditions.
# ans: action done by suction is suction
# pred: The bipolar forceps are located on the heart, which is a vital organ in the chest cavity.
# ans: bipolar forceps is located at left-top
# pred: The ProGrasp forceps is a surgical instrument used for grasping and retracting tissues during surgery. It is commonly used in minimally invasive surgical procedures, such as laparoscopic or endoscopic surgery.
#
# The ProGrasp forceps is typically placed through a small incision or port and is designed to be inserted into the body cavity where the procedure is being performed. The forceps are then used to grasp and manipulate the tissues, allowing the surgeon to perform the necessary procedures.
#
# In the image, the ProGrasp forceps is located in the abdominal cavity, likely during a laparoscopic procedure. The forceps are visible as a series of metal loops with a handle on one end, and are attached to a cable or tube that connects them to the surgical console or robotic system.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the heart, as shown in the image.
# ans: monopolar curved scissors is located at right-top
# pred: The suction is located on the heart, specifically on the left ventricle, which is the lower chamber of the heart that pumps blood into the aorta.
# ans: suction is located at right-top
# pred: The organ being operated on in the image is the stomach. The surgeon is performing a laparoscopic surgery, which involves making small incisions in the abdominal wall to insert a camera and surgical instruments to visualize and operate on the internal organs. In this case, the camera and instruments are being used to operate on the stomach, which is visible in the image as a pinkish-red organ with blood vessels and a gastric pouch. The presence of the stomach in the image suggests that the surgery is likely related to a gastric procedure, such as a laparoscopic gastrectomy or a laparoscopic gastric bypass.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps and needles.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are in an open position.
# ans: action done by bipolar forceps is idle
# pred: The prograsp forceps are in an open position.
# ans: action done by prograsp forceps is idle
# pred: The image shows a close-up view of a surgical procedure, with the focus on a pair of monopolar curved scissors. The scissors are held by a surgeon's hand, with the blades open and ready to cut tissue. The scissors are likely being used to cut a suture or a ligament during a surgical procedure.
#
# *Answer*: Open
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are located in the abdomen, specifically in the abdominal cavity, where they are used for surgical procedures such as laparoscopic surgery.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are a type of surgical instrument used in laparoscopic surgery to grasp and manipulate tissue. They are typically located in the sterile field, which is the area within the abdominal cavity where the surgical procedure is being performed. The Prograsp forceps are held by the surgeon's hands and are used to grasp and manipulate the tissue or organ being operated on.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the lower right corner of the image, held by a hand.
# ans: monopolar curved scissors is located at right-top
# pred: The organ being operated on appears to be the heart, as indicated by the presence of a cardiopulmonary bypass machine and surgical instruments.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including a surgical suture and a surgical clamp.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The bipolar forceps are in an intraoperative state, as indicated by the presence of the instrument in the image and the surgical incision and sutures visible around it.
# ans: action done by bipolar forceps is idle
# pred: The state of ProGrasp forceps is that they are a type of surgical instrument used to grasp and manipulate tissues in minimally invasive surgery, particularly in laparoscopic and thoracoscopic procedures. They are designed to provide a secure and atraumatic grasp of tissues, allowing for precise dissection and manipulation during surgery.
# ans: action done by prograsp forceps is idle
# pred: The state of the monopolar curved scissors is that they are being used in a surgical procedure, as indicated by the presence of a surgical instrument in the image. The scissors are likely being used to cut or dissect tissue, and the curved shape suggests that they are designed for precise cutting or dissection in tight spaces.
# ans: action done by monopolar curved scissors is cauterization
# pred: Bipolar forceps are located in the abdomen, specifically in the abdominal cavity. They are used for laparoscopic or open surgical procedures to grasp, cut, and coagulate tissues.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are located in the abdominal cavity, specifically in the upper left quadrant.
# ans: prograsp forceps is located at left-top
# pred: **Step 1: Identify the instrument**
#
# The instrument is a monopolar curved scissors.
#
# **Step 2: Identify the location**
#
# The instrument is being used in the abdominal cavity, specifically in the vicinity of the liver.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated is the stomach. The image shows a surgical procedure on the stomach, with the surgeon's hands visible and the stomach partially opened to expose its contents. The presence of the stomach and the surgical instruments suggest that this is a surgical operation on the stomach.
# ans: organ being operated is kidney
# pred: The organ being operated on is the kidney, and the tools operating it are a laparoscope and an ultrasonic lithotripter.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The bipolar forceps are in an open state, as shown in the image.
# ans: action done by bipolar forceps is idle
# pred: The ProGrasp forceps are in a state of being used to grasp and manipulate the uterus during a laparoscopic procedure, as indicated by the image.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is shown in the image as being used to cut the stomach. The scissors are positioned inside the stomach, with the curved part of the scissors visible and the handle held by an individual. The scissors are likely being used to make a incision in the stomach wall for a surgical procedure, such as a partial gastrectomy or a gastric bypass surgery. The image suggests that the scissors are being used to cut through the stomach muscle and serosa, which is a common step in many gastrointestinal surgeries.
# ans: action done by monopolar curved scissors is cutting
# pred: Bipolar forceps are typically located in the abdominal cavity, specifically in the area of the uterus. They are used for surgical procedures such as hysterectomy and myomectomy.
# ans: bipolar forceps is located at left-top
# pred: The prograsp forceps are located in the abdominal cavity, specifically around the gallbladder.
# ans: prograsp forceps is located at left-top
# pred: The instrument in the image is a monopolar curved scissors, which is a type of surgical instrument used for cutting and dissecting tissues. It is located in the abdominal cavity, specifically in the pelvis, where it is being used to cut and remove tissue.
# ans: monopolar curved scissors is located at right-top
# pred: The organ being operated on is the diaphragm. The diaphragm is a dome-shaped muscle that separates the chest cavity from the abdominal cavity, and it plays a crucial role in breathing by contracting and relaxing to facilitate inhalation and exhalation. In this image, the diaphragm appears to be being operated on to repair a tear or injury, which is a common surgical procedure to treat diaphragmatic hernias or other conditions that affect the diaphragm's function.
# ans: organ being operated is kidney
# pred: The image depicts a surgical procedure, likely a laparoscopic surgery, where the organs are being operated on by a laparoscope and surgical instruments.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are a type of surgical instrument used to grasp and hold tissue or organs during surgical procedures. They are called "bipolar" because they have two prongs that can be opened and closed to grasp or clamp onto tissue.
#
# In the image, the bipolar forceps are shown with their prongs closed, ready to grasp the tissue. The forceps are typically made of metal and have a smooth, curved surface to prevent damage to the tissue. They are commonly used in laparoscopic surgery, where they are inserted through small incisions to perform procedures such as laparoscopic cholecystectomy (gallbladder removal) or laparoscopic hysterectomy (uterus removal).
#
# The bipolar forceps are designed to minimize tissue trauma and promote hemostasis, which is the control of bleeding. They are also useful for dissecting and separating tissues, as well as for applying pressure to control bleeding.
#
# Overall, the bipolar forceps play an important role in many surgical procedures, allowing surgeons to perform precise and minimally invasive surgeries with minimal risk of complications.
# ans: action done by bipolar forceps is idle
# pred: The state of the ProGrasp forceps in the image is closed.
# ans: action done by prograsp forceps is retraction
# pred: The state of the monopolar curved scissors in the image is that they are being used to cut tissue, as indicated by the silver blades and the presence of a surgical instrument in the image.
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are a type of surgical instrument used in medical procedures, particularly in laparoscopic surgery. They are located in the abdominal cavity, specifically in the abdominal wall, where they are used to grasp and manipulate tissues or organs.
#
# **Step 1: Understanding the Instrument**
#
# Bipolar forceps are a type of forceps that can be used to grasp and manipulate tissues or organs in the abdominal cavity. They have two prongs that are connected by a handle, allowing for precise control and manipulation.
#
# **Step 2: Locating the Instrument**
#
# To locate bipolar forceps in the abdominal cavity, we need to consider the anatomy of the abdominal wall and the types of surgeries where these instruments are commonly used. The abdominal cavity is a complex area with various organs and structures, including the stomach, small intestine, liver, pancreas, and more.
#
# **Step 3: Common Surgical Procedures**
#
# Bipolar forceps are often used in laparoscopic surgery, which involves making small incisions in the abdominal wall and using a camera and light to visualize the internal organs. Common procedures where bipolar forceps are used include:
#
# * Laparoscopic cholecystectomy (removal of the gallbladder)
# * Laparoscopic hysterectomy (removal of the uterus)
# * Laparoscopic appendectomy (removal of the appendix)
# * Laparoscopic colectomy (removal of part of the colon)
#
# **Step 4: Visualizing the Instrument**
#
# In these procedures, the bipolar forceps are inserted through the small incisions and used to grasp and manipulate the tissues or organs. The instrument is typically held by the surgeon's hand and used to perform various tasks, such as cutting, grasping, and dissecting.
#
# **Step 5: Conclusion**
#
# In conclusion, bipolar forceps are located in the abdominal cavity, specifically in the abdominal wall, where they are used in laparoscopic surgery to grasp and manipulate tissues or organs. They are commonly used in various surgical procedures, including laparoscopic cholecystectomy, laparoscopic hysterectomy, laparoscopic appendectomy, and laparoscopic colectomy.
# ans: bipolar forceps is located at left-bottom
# pred: The ProGrasp forceps is a surgical instrument used in laparoscopic surgery. It is a type of grasping forceps that is designed to be used through small incisions, allowing for minimally invasive procedures.
#
# **Step 1: Understand the context of the image**
#
# The image provided shows a close-up view of a surgical site with various instruments visible. The instruments are used in a laparoscopic procedure, which involves making small incisions in the skin and using a camera and light to visualize the internal organs on a monitor.
#
# **Step 2: Identify the ProGrasp forceps**
#
# The ProGrasp forceps is a specialized instrument used in laparoscopic surgery. It has a unique design that allows it to be inserted through small incisions and manipulated through the abdominal wall to grasp and manipulate tissues or organs inside the abdominal cavity.
#
# **Step 3: Locate the ProGrasp forceps in the image**
#
# In the given image, the ProGrasp forceps is located on the right side of the image. It is visible as a long, thin instrument with a curved tip and a series of small jaws that can open and close to grasp tissue. The forceps is attached to a long, flexible shaft that connects it to the laparoscope, which is the camera system used to visualize the internal organs.
#
# **Step 4: Confirm the location**
#
# To confirm the location of the ProGrasp forceps, we can look for the following features:
#
# * The forceps is attached to a long, flexible shaft that connects it to the laparoscope.
# * The forceps has a curved tip and a series of small jaws that can open and close to grasp tissue.
# * The forceps is located on the right side of the image, near the top.
#
# **Answer:** The ProGrasp forceps is located on the right side of the image, near the top.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located on the left side of the image, near the top.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on in the image is the **kidney**. The kidney is a vital organ responsible for filtering waste and excess fluids from the blood and regulating electrolyte levels in the body. It plays a crucial role in maintaining overall health and well-being.
#
# **Step 1: Identify the Structure**
#
# The structure visible in the image is a kidney, which is a bean-shaped organ located in the lower back on either side of the spine. It is part of the urinary system and has a complex network of blood vessels and nephrons that filter waste and excess fluids from the blood.
#
# **Step 2: Confirm the Structure**
#
# To confirm that the structure is indeed a kidney, we can look for the characteristic features of the kidney, such as its bean-like shape, the presence of renal cortex and medulla, and the renal pelvis. The image shows a kidney with these features.
#
# **Step 3: Analyze the Context**
#
# The context of the image suggests that the kidney is being operated on, possibly for a medical procedure such as a nephrectomy (removal of the kidney) or a nephroureterectomy (removal of the kidney and the ureter). The presence of surgical instruments and sutures in the image supports this interpretation.
#
# **Conclusion**
#
# Based on the visual characteristics of the structure and the context of the image, it is clear that the organ being operated on is the **kidney**.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, which are used to perform a surgical procedure. The specific tools visible in the image are sutures, a retractor, and a clamp.
# ans: the tools operating are prograsp forceps , monopolar curved scissors
# pred: The prograsp forceps is in a state of being used for laparoscopic surgery, as indicated by the presence of a laparoscope and surgical instruments in the image.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors in the image is that they are currently being used in a surgical procedure, as indicated by their presence in the abdominal cavity and the presence of sutures and other surgical instruments nearby.
# ans: action done by monopolar curved scissors is tissue manipulation
# pred: The ProGrasp forceps is a medical instrument used in surgical procedures, particularly in laparoscopic surgery. It is designed to grasp and manipulate tissues, organs, or other objects within the abdominal cavity.
#
# **Step 1: Understanding the Context**
#
# To determine where the ProGrasp forceps is located, we need to understand its purpose and how it is used. The ProGrasp forceps is typically used in minimally invasive surgical procedures, such as laparoscopy, where small incisions are made to insert a camera and instruments. This allows for the visualization and manipulation of internal organs without the need for open surgery.
#
# **Step 2: Identifying the Instrument**
#
# The ProGrasp forceps is a type of grasper, which is a common instrument in laparoscopic surgery. Graspers are used to hold and manipulate tissues, organs, or objects within the body. They come in various shapes and sizes, depending on their intended use.
#
# **Step 3: Locating the ProGrasp Forceps**
#
# Given the description of the ProGrasp forceps as a grasper used in laparoscopic surgery, it is likely located in the abdominal cavity. This is where the instrument is inserted through a small incision and used to grasp and manipulate internal organs or tissues.
#
# **Step 4: Conclusion**
#
# Based on the information provided and the typical use of graspers in laparoscopic surgery, the ProGrasp forceps is located in the abdominal cavity, specifically for use in minimally invasive surgical procedures.
# ans: prograsp forceps is located at left-top
# pred: **Step 1: Identify the object in the image**
#
# The object in the image is a pair of curved scissors.
#
# **Step 2: Identify where the curved scissors are located**
#
# The curved scissors are located in the middle of the image, inside a human body. The curved scissors are used in surgery, likely in the abdominal cavity.
#
# **Conclusion**
#
# The curved scissors are located in the abdominal cavity of a human body.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the stomach, as evidenced by the presence of the laparoscope and surgical instruments.
# ans: organ being operated is kidney
# pred: The image depicts a surgical procedure in progress, with a laparoscope and its lighted sheath positioned at the top of the image, and a pair of forceps visible at the bottom. The forceps are used to grasp and manipulate the organ being operated on, while the laparoscope provides a clear view of the surgical site.
# ans: the tools operating are prograsp forceps , monopolar curved scissors
# pred: The state of the prograsp forceps is that it is being used to grasp and hold a small bowel loop.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The monopolar curved scissors are shown in the image as being used to cut tissue. The scissors are curved and have a white handle, indicating that they are likely used for precise cutting in a specific area, such as during surgery.
# ans: action done by monopolar curved scissors is idle
# pred: The prograsp forceps is located in the abdomen, as shown in the image. The forceps are being used to grasp and manipulate tissues within the abdominal cavity.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the lower right abdomen, as shown in the image.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on appears to be the kidney, as evidenced by the presence of a renal artery and renal vein in the surgical field.
# ans: organ being operated is kidney
# pred: The image depicts a surgical procedure, specifically a cardiac surgery, where the heart is being operated on. The tools visible in the image are:
#
# *   **Sutures**: The white, curved lines are sutures, which are used to close wounds or incisions made during the surgery. They are typically made of a non-reactive material, such as nylon or polyester, and come in various sizes and types to accommodate different tissues and organs.
# *   **Retractors**: The black and gray objects are retractors, which are used to hold back tissues and organs to provide access to the area being operated on. They are usually made of metal or plastic and come in different shapes and sizes to suit the specific needs of the surgery.
# *   **Scissors**: The silver object in the top-left corner is a pair of scissors, which are used to cut sutures or other materials during the surgery.
# *   **Clamps**: The silver object in the bottom-left corner is a clamp, which is used to hold or compress blood vessels or other tissues during the surgery. Clamps can be used to control bleeding, provide traction, or apply pressure to specific areas.
#
# These tools are commonly used in cardiac surgery to perform procedures such as coronary artery bypass grafting, heart valve repair or replacement, and cardiac transplantation. The use of these tools requires a high level of skill and precision to ensure a successful outcome and minimize complications.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The state of bipolar forceps is not explicitly stated in the image, but based on the context of the image, which appears to be a medical or surgical setting, it can be inferred that the forceps are likely in a sterile and ready-to-use state.
# ans: action done by bipolar forceps is idle
# pred: The ProGrasp forceps are a type of surgical instrument used in minimally invasive surgery, such as laparoscopy. They are designed to grasp and manipulate tissues, allowing for precise control and manipulation of the tissue.
#
# **Step 1: Understanding the ProGrasp Forceps**
#
# The ProGrasp forceps are a type of grasping forceps that are commonly used in laparoscopic surgery. They have a unique design that allows them to grasp and manipulate tissues with precision.
#
# **Step 2: State of ProGrasp Forceps**
#
# The ProGrasp forceps are typically used in a closed state, with the jaws closed around the tissue. This allows for a secure grip on the tissue, enabling the surgeon to manipulate it with precision.
#
# **Step 3: Manipulation and Tissue Handling**
#
# Once the ProGrasp forceps are in place, the surgeon can manipulate the tissue by opening and closing the jaws. This allows for precise control over the tissue, enabling the surgeon to perform a variety of tasks, such as dissecting, cutting, or suturing.
#
# **Step 4: Conclusion**
#
# In conclusion, the ProGrasp forceps are used in a closed state to grasp and manipulate tissues during minimally invasive surgery. Their unique design allows for precise control and manipulation of the tissue, making them an essential tool in many surgical procedures.
#
# *Answer*: Closed
# ans: action done by prograsp forceps is tissue manipulation
# pred: **Step 1: Identify the instrument**
#
# The instrument in the image is a monopolar curved scissors.
#
# **Step 2: Determine the state**
#
# The instrument is shown in a closed position.
# ans: action done by monopolar curved scissors is tissue manipulation
# pred: Bipolar forceps are located in the abdominal cavity, specifically in the peritoneal cavity. They are a type of surgical instrument used for grasping and manipulating tissues during laparoscopic or open surgery.
# ans: bipolar forceps is located at left-bottom
# pred: The ProGrasp forceps is a surgical instrument used to grasp and manipulate tissue, particularly in laparoscopic and endoscopic procedures. It is commonly used in various surgical specialties, including urology, gynecology, and general surgery.
#
# The ProGrasp forceps is typically located in the instrument tray or on the laparoscope, depending on the specific surgical procedure being performed. It is usually held by the surgeon's right hand and used to grasp and manipulate tissue during the procedure.
#
# The ProGrasp forceps is designed to provide a secure and atraumatic grip on the tissue, allowing for precise manipulation and dissection. It is often used in conjunction with other surgical instruments, such as scissors, retractors, and graspers, to facilitate the surgical procedure.
# ans: prograsp forceps is located at left-top
# pred: The image depicts a surgical procedure, likely an abdominal surgery, where a monopolar curved scissors is visible. The scissors is positioned in the upper right portion of the image, above the heart and the aorta. It is attached to a black cord or cable that runs along the right side of the image. The scissors is also attached to a metal instrument on the left side of the image.
# ans: monopolar curved scissors is located at right-top
# pred: The organ being operated on is the stomach. The image shows a laparoscopic view of the stomach, with the surgeon's instruments visible and the stomach's lining visible. The presence of the stomach lining and the instruments used in the procedure suggest that the surgery is taking place within the abdominal cavity, specifically targeting the stomach.
# ans: organ being operated is kidney
# pred: The tools operating the organ are laparoscopic instruments, which are typically used in minimally invasive surgery. The instruments include a grasper, scissors, and a clip applier, which are all commonly used in laparoscopic procedures.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The state of bipolar forceps is active, as indicated by the image showing it being used in a surgical procedure.
# ans: action done by bipolar forceps is idle
# pred: The prograsp forceps is in a closed position.
# ans: action done by prograsp forceps is retraction
# pred: The instrument in the image is a monopolar curved scissors, which is a type of surgical instrument used for cutting and dissecting tissues. The curved shape of the scissors allows for precise dissection and cutting in tight spaces, making it useful for various surgical procedures.
#
# *Answer*: Active
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are located in the abdomen, specifically in the abdominal cavity. They are used to grasp and manipulate tissues during surgical procedures.
# ans: bipolar forceps is located at left-bottom
# pred: The prograsp forceps is located in the upper left corner of the image.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located in the abdominal cavity, specifically in the pelvic region. The curved shape of the scissors allows for precise dissection and cutting of tissues in the pelvic area, which is a common location for various surgical procedures.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on in the image is the stomach. The image shows a surgical procedure being performed on the stomach, with instruments and sutures visible in the abdominal cavity. The presence of these instruments and sutures suggests that the procedure is a surgical intervention aimed at addressing a condition or issue related to the stomach.
#
# *Answer*: Stomach
# ans: organ being operated is kidney
# pred: The tools operating the organ are a laparoscope, forceps, and a needle driver. The laparoscope is used to visualize the area of the organ that needs to be operated on. The forceps are used to grasp and hold the organ in place, while the needle driver is used to pass sutures through the organ and tie them off.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are in a state of being used in surgery, as evidenced by their presence in the image alongside surgical instruments and a surgical site.
# ans: action done by bipolar forceps is idle
# pred: The image shows a close-up view of the abdomen with various surgical instruments and sutures visible. The prograsp forceps are in the center of the image, with a suture threaded through them. The forceps are holding the suture in place, which is wrapped around a metal clip. The suture is tied off with a knot, indicating that it has been secured in place.
#
# *Answer*: Closed
# ans: action done by prograsp forceps is idle
# pred: The state of the monopolar curved scissors is that they are in use, as evidenced by the image showing them being used to cut tissue.
# ans: action done by monopolar curved scissors is idle
# pred: The bipolar forceps are located in the lower left corner of the image.
# ans: bipolar forceps is located at left-bottom
# pred: The prograsp forceps is located in the upper right hand corner of the image, as shown by the white and gold color and the long, thin shape.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located on the left side of the image, as indicated by the white handle and curved tip.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on in the image is the stomach. The image shows a surgical procedure involving the stomach, with the presence of a laparoscope and surgical instruments, which are commonly used in laparoscopic surgery. The stomach is a muscular organ that plays a crucial role in digestion and absorption of food, and surgical procedures on the stomach are often performed to address conditions such as ulcers, cancer, or other gastrointestinal issues.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including a scalpel, forceps, and sutures.
# ans: the tools operating are bipolar forceps , monopolar curved scissors
# pred: Bipolar forceps are a type of surgical instrument used to grasp and manipulate tissue during surgical procedures. They are called "bipolar" because they have two prongs or jaws that can be opened and closed to grasp and hold onto tissue.
#
# In the image, the bipolar forceps are being used to grasp a piece of tissue, likely during a surgical procedure. The forceps are held by a surgeon's hand, with the prongs closed around the tissue. The tissue appears to be a section of intestine or other organ, and the forceps are being used to grasp and manipulate it.
#
# The state of the bipolar forceps is one of tension, as they are being used to hold onto the tissue firmly. The forceps are also likely being used to apply gentle traction to the tissue, which is a common technique in surgery to help guide and manipulate tissues during a procedure.
#
# Overall, the bipolar forceps are in a state of tension and are being used to perform a specific surgical task, likely to grasp and manipulate tissue for further examination or treatment.
# ans: action done by bipolar forceps is idle
# pred: The state of the monopolar curved scissors is that they are being used to cut through tissue, as indicated by the image.
# ans: action done by monopolar curved scissors is cauterization
# pred: Bipolar forceps are located in the abdomen.
# ans: bipolar forceps is located at left-bottom
# pred: The monopolar curved scissors is located in the middle of the image, to the right of the image. The curved shape of the scissors indicates that it is used for cutting or dissecting tissues in a curved or angled manner. The monopolar curved scissors is likely being used to cut or dissect the tissues in the abdominal cavity, possibly during a surgical procedure such as a laparoscopy.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the eye, as indicated by the presence of the surgical instruments and the exposure of the eye's interior.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps and a scalpel.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are a surgical instrument used for coagulating or cutting tissue. They are typically used in conjunction with an electrosurgical unit to apply electrical energy to the tissue.
#
# **Step 1: Understanding the Basics**
#
# * Bipolar forceps are designed to apply electrical energy between two points of the instrument.
# * The forceps have two prongs or arms that can be closed to grasp and hold tissue.
# * When the forceps are closed, they create a small gap between the two prongs.
#
# **Step 2: Applying Electrical Energy**
#
# * When the electrosurgical unit is activated, it sends electrical energy through the forceps.
# * The energy is concentrated between the two prongs of the forceps.
# * The electrical energy can either coagulate (heat and seal) the tissue or cut it, depending on the settings of the electrosurgical unit.
#
# **Step 3: Coagulation or Cutting**
#
# * If the electrosurgical unit is set for coagulation, the electrical energy heats the tissue between the forceps, causing it to seal itself.
# * If the unit is set for cutting, the electrical energy creates a high-frequency electrical current that cuts the tissue.
#
# **Step 4: Conclusion**
#
# The state of bipolar forceps is typically one of readiness to apply electrical energy to tissue for coagulation or cutting, as needed in various surgical procedures.
# ans: action done by bipolar forceps is idle
# pred: The ProGrasp forceps are in an open position, as indicated by the curved tips and the visible teeth.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is that they are being used in a surgical procedure, as indicated by the presence of a scalpel and the fact that they are part of a surgical instrument.
# ans: action done by monopolar curved scissors is cutting
# pred: The bipolar forceps is located in the eye, specifically in the anterior chamber of the eye, where it is used to grasp and remove small tissue fragments or debris during eye surgery.
# ans: bipolar forceps is located at left-top
# pred: Prograsp forceps are a type of surgical instrument used in laparoscopic surgery, and they are typically located in the abdominal cavity. They are designed to grasp and retract tissues, allowing the surgeon to visualize and manipulate internal organs or tissues during the procedure.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the eye, as shown in the image. The curved scissors are used to cut and manipulate tissue during eye surgery, such as cataract removal or vitreoretinal surgery. The curved shape of the scissors allows for precise dissection and cutting of delicate tissues, while the monopolar feature provides precise control over the cutting action.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the stomach. The image shows a laparoscopic view of the stomach, with the surgeon's instrument visible in the foreground and the stomach's interior visible in the background. The stomach appears to be undergoing a surgical procedure, possibly a laparoscopic cholecystectomy or a laparoscopic gastrectomy.
# ans: organ being operated is kidney
# pred: The tools operating the organ are a laparoscope and a surgical instrument.
# ans: the tools operating are prograsp forceps , monopolar curved scissors , suction
# pred: The prograsp forceps is in a closed position.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is that they are being used in a surgical procedure, as indicated by the presence of the scissors and the surgical instruments in the image.
# ans: action done by monopolar curved scissors is cauterization
# pred: The suction is in the state of being applied to the area of the abdomen.
# ans: action done by suction is idle
# pred: The prograsp forceps is located in the upper left-hand side of the image, with its jaws positioned around the liver tissue.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located at the bottom left of the image. They are a type of surgical instrument used for cutting and dissecting tissues in laparoscopic surgery. The curved shape of the scissors allows for precise dissection and cutting in tight spaces, making them ideal for procedures such as laparoscopic cholecystectomy (gallbladder removal) and laparoscopic hysterectomy (uterus removal).
# ans: monopolar curved scissors is located at right-bottom
# pred: The suction is located on the right side of the image, specifically at the top. It is attached to a metal clip and appears to be connected to a tube or hose that leads to a medical device or instrument.
# ans: suction is located at right-top
# pred: The organ being operated on appears to be the stomach, as evidenced by the presence of a surgical incision and the presence of sutures in the abdominal cavity.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps, retractors, and sutures.
# ans: the tools operating are bipolar forceps , monopolar curved scissors
# pred: The bipolar forceps are in a state of being used to hold and manipulate tissues during surgery, with the forceps being held by the surgeon's hand.
# ans: action done by bipolar forceps is idle
# pred: The monopolar curved scissors is in an open position.
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are typically located in the operating room, specifically in the instrument tray or on the surgical table. They are used to grasp and hold tissue or organs during surgical procedures, and are an essential tool for many surgical specialties.
# ans: bipolar forceps is located at left-bottom
# pred: The monopolar curved scissors are located in the upper right side of the image, as indicated by the white handle and curved shape of the instrument.
# ans: monopolar curved scissors is located at right-top
# pred: The organ being operated on appears to be the stomach. The instrument in the image is a laparoscope, which is used to visualize the internal organs. The presence of the instrument suggests that the procedure is a laparoscopic surgery, which is a minimally invasive surgical technique that allows for the visualization of internal organs through small incisions. The stomach is one of the organs that can be accessed and operated on using laparoscopy.
# ans: organ being operated is kidney
# pred: The tools operating the organ are a laparoscope, forceps, and a stapler.
# ans: the tools operating are prograsp forceps , monopolar curved scissors
# pred: The prograsp forceps is in an open state.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The monopolar curved scissors are in an "open" position.
# ans: action done by monopolar curved scissors is cauterization
# pred: The prograsp forceps is located in the lower left of the image.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located on the left side of the image, near the top.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the stomach, as indicated by the presence of the stomach staples and the surgical instruments.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including a surgical stapler and scissors.
# ans: the tools operating are bipolar forceps , prograsp forceps , clip applier
# pred: The state of bipolar forceps is "open".
# ans: action done by bipolar forceps is idle
# pred: The state of ProGrasp forceps is "open".
# ans: action done by prograsp forceps is retraction
# pred: The clip applier is in the state of being opened, as indicated by the open jaws and the absence of a clip in place.
# ans: action done by clip applier is clipping
# pred: Bipolar forceps are located in the abdominal cavity, specifically in the pelvis and near the uterus.
# ans: bipolar forceps is located at left-bottom
# pred: ProGrasp forceps are a type of surgical instrument used in minimally invasive surgery, particularly in laparoscopic procedures. They are typically located in the surgeon's hand, held by the surgeon during the operation.
#
# The ProGrasp forceps are designed to grasp and manipulate tissue, allowing the surgeon to perform various tasks such as cutting, dissecting, and suturing. They are commonly used in procedures like laparoscopic cholecystectomy (gallbladder removal), laparoscopic hysterectomy (uterus removal), and laparoscopic hernia repair.
#
# The ProGrasp forceps are part of the ProGrasp EndoWrist system, which is a versatile and ergonomic instrument designed to provide a secure and stable grasp on tissues, allowing for precise control and manipulation during laparoscopic procedures.
# ans: prograsp forceps is located at left-bottom
# pred: The clip applier is located on the right side of the image, near the top. It is a small, metal device with a long handle and a clip at the end. The clip is used to grasp and hold onto tissue or other structures during surgical procedures.
# ans: clip applier is located at right-bottom
# pred: The organ being operated on is the stomach. The image shows a surgical procedure involving the stomach, with the presence of sutures and instruments in the abdominal cavity, indicating that the surgery is taking place within the stomach.
# ans: organ being operated is kidney
# pred: The image shows a surgical procedure involving a patient's mouth, with various tools and instruments visible. The tools appear to be dental instruments, including forceps, retractors, and sutures.
#
# *   **Forceps**: The forceps are used to hold and manipulate the teeth or surrounding tissues during the procedure.
# *   **Retractors**: The retractors are used to hold back the lips and gums to provide a clear view of the surgical site.
# *   **Sutures**: The sutures are used to close the incision after the procedure is complete.
#
# The tools are likely being used by a dentist or oral surgeon to perform a dental procedure, such as a tooth extraction or oral surgery.
# ans: the tools operating are prograsp forceps , monopolar curved scissors , suction
# pred: The prograsp forceps are in a state of being used to hold and manipulate the tissue, as indicated by the presence of sutures and the visible tissue surrounding the forceps.
# ...
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors is located on the left side of the image, positioned between the heart and the metal instrument on the left side.
# ans: monopolar curved scissors is located at right-top
# pred: Suction is located in the heart, specifically in the right ventricle, where it is used to remove blood from the heart and circulatory system.
# ans: suction is located at right-top
# pred: The organ being operated is the stomach, as indicated by the presence of a laparoscope and surgical instruments visible in the image.
# ans: organ being operated is kidney
# pred: The image depicts a surgical procedure, with the tools operating the organ being surgical instruments. The instruments visible in the image are:
#
# *   **Suction Irrigator-Aspirator**: This instrument is used to remove fluid, blood, or other debris from the surgical site. It has a curved, hollow tip that can be inserted into the body to aspirate fluid.
# *   **Electrocautery**: This instrument is used to cauterize or cut tissue using electrical energy. It has a sharp, pointed tip that can be used to make precise incisions or coagulate bleeding vessels.
# *   **Surgical Scissors**: These scissors are used to cut tissue. They have sharp blades that can be used to make precise cuts in the organ.
#
# These instruments are commonly used in laparoscopic surgery, which is a minimally invasive surgical technique that uses small incisions and specialized instruments to perform operations. The instruments are inserted through these small incisions, allowing for minimal tissue damage and faster recovery times compared to traditional open surgery.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors , clip applier
# pred: Bipolar forceps are in an open state.
# ans: action done by bipolar forceps is idle
# pred: The state of the prograsp forceps is that it is being used to grasp and manipulate tissue, as indicated by the image. The forceps are positioned to hold onto a specific area of tissue, which suggests that they are being used for a surgical procedure.
# ans: action done by prograsp forceps is retraction
# pred: The state of the monopolar curved scissors in the image is that they are being used to cut tissue, as indicated by the presence of a surgical instrument with a curved tip and a clear plastic or metal blade. The scissors are likely being used for a surgical procedure, such as laparoscopic surgery, where they are inserted through small incisions to perform precise cuts and dissections.
#
# *Answer*: The monopolar curved scissors are in the "cutting" state.
# ans: action done by monopolar curved scissors is idle
# pred: The state of the clip applier is likely to be closed, as it is used to hold or secure something in place.
# ans: action done by clip applier is idle
# pred: Bipolar forceps are located in the middle of the image, specifically in the center of the surgical field.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are located in the upper right of the image, positioned above the suture material.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located on the left side of the image, just above the heart.
# ans: monopolar curved scissors is located at right-bottom
# pred: The clip applier is located on the right side of the image, with its tip positioned near the top of the image.
# ans: clip applier is located at right-bottom
# pred: The organ being operated on is the stomach, as indicated by the presence of a stomach retractor and the surgical sutures visible in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are a surgical retractor, a suction irrigator, and a clamp.
# ans: the tools operating are bipolar forceps , monopolar curved scissors
# pred: The state of bipolar forceps is open, as indicated by the image.
# ans: action done by bipolar forceps is grasping
# pred: The image shows a monopolar curved scissors in its open position.
# ans: action done by monopolar curved scissors is cauterization
# pred: Bipolar forceps are located in the abdominal cavity.
# ans: bipolar forceps is located at left-top
# pred: The monopolar curved scissors is located on the right side of the image.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the appendix, as indicated by the presence of the appendix clips and the laparoscope in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are the laparoscopic tools, which are commonly used in minimally invasive surgery.
# ans: the tools operating are bipolar forceps , prograsp forceps , clip applier
# pred: **Step 1: Understand the context of the question.**
#
# The question asks about the state of bipolar forceps, which are a type of surgical instrument used for coagulation and cutting during laparoscopic or endoscopic procedures.
#
# **Step 2: Identify the correct answer based on the given options.**
#
# In this case, the correct answer is "open" because bipolar forceps are typically used to grasp and manipulate tissues while being able to apply heat to coagulate or cut the tissue.
#
# **Step 3: Provide the final answer.**
#
# *Answer*: Open
# ans: action done by bipolar forceps is idle
# pred: The state of the ProGrasp forceps is closed.
# ans: action done by prograsp forceps is idle
# pred: The state of the clip applier in the image is that it is open.
# ans: action done by clip applier is clipping
# pred: The bipolar forceps are located in the lower right corner of the image, near the bottom of the abdomen.
# ans: bipolar forceps is located at left-bottom
# pred: The ProGrasp forceps is a type of robotic forceps used in minimally invasive surgery. It is designed to grasp and manipulate tissues during laparoscopic or robotic surgery. The ProGrasp forceps is located in the instrument tray of a robotic surgical system, such as the da Vinci Surgical System. It is typically placed in the left or right hand of the robotic system, depending on the surgical procedure being performed.
#
# The ProGrasp forceps is used to grasp and manipulate tissues, such as organs or blood vessels, during surgery. It is designed to be precise and delicate, allowing surgeons to perform complex procedures with high accuracy. The forceps is also equipped with advanced features, such as tissue grasping and cutting capabilities, which enable surgeons to perform a variety of tasks during surgery.
#
# In addition to its use in robotic surgery, the ProGrasp forceps is also used in laparoscopic surgery, where it is inserted through a small incision in the abdomen to perform procedures such as gallbladder removal or hysterectomy. The forceps is also used in endoscopic surgery, where it is inserted through a small incision in the body to perform procedures such as colonoscopy or bronchoscopy.
#
# Overall, the ProGrasp forceps is an important tool in minimally invasive surgery, allowing surgeons to perform complex procedures with precision and accuracy.
# ans: prograsp forceps is located at left-bottom
# pred: The clip applier is located in the center of the image, between the two clips already placed.
# ans: clip applier is located at right-bottom
# pred: The organ being operated is the heart, as indicated by the presence of the heart-lung machine and the surgical instruments visible in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are a pair of forceps and a laser, as indicated by the visible light beam and the forceps grasping the organ.
# ans: the tools operating are prograsp forceps , monopolar curved scissors , suction
# pred: The state of the ProGrasp forceps is activated, as indicated by the visible grasp.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The monopolar curved scissors is in an active state, as indicated by the presence of sparks or electrical discharge emanating from it. This suggests that the scissors is currently in use and is being utilized to cut or dissect tissue.
# ans: action done by monopolar curved scissors is cauterization
# pred: The state of suction is one of negative pressure.
# ans: action done by suction is idle
# pred: Prograsp forceps are located in the abdomen, specifically in the pelvic region.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors is located in the upper right hand.
# ans: monopolar curved scissors is located at right-bottom
# pred: The suction is located at the top of the heart.
# ans: suction is located at right-top
# pred: The organ being operated on is the kidney.
# ans: organ being operated is kidney
# pred: The tools operating the organ are the laparoscope, which is a long, thin tube with a camera and light on the end, and the surgical scissors, which are used to cut and manipulate the organ.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are in an open state.
# ans: action done by bipolar forceps is idle
# pred: The state of the ProGrasp forceps is as follows:
#
# * The forceps are in the "open" position, ready to grasp and hold the tissue.
# * They are positioned near the tissue, indicating they are being used to grasp and manipulate the tissue during the procedure.
# * The jaws of the forceps are closed, but not yet in contact with the tissue, suggesting they are about to grasp it.
#
# This indicates that the forceps are in a state of readiness to perform their function of grasping and manipulating the tissue, but not yet in contact with it.
# ans: action done by prograsp forceps is retraction
# pred: The instrument in the image is a monopolar curved scissors, which is a type of surgical instrument used for cutting and dissecting tissue. The scissors are typically used in laparoscopic or endoscopic procedures, where they are inserted through small incisions to perform various surgical tasks.
#
# **Step 1: Identify the instrument**
#
# The instrument in the image is a monopolar curved scissors, which is a type of surgical instrument used for cutting and dissecting tissue.
#
# **Step 2: Determine the state of the instrument**
#
# The instrument is in an active state, meaning it is being used to perform a surgical procedure. The curved shape of the scissors suggests that it is designed for precise cutting and dissecting tasks.
#
# **Step 3: Consider the context of the image**
#
# The image appears to be a medical or surgical setting, with the instrument being used in a laparoscopic or endoscopic procedure. The presence of other instruments and equipment in the background suggests that the instrument is part of a surgical team or team.
#
# **Step 4: Draw a conclusion**
#
# Based on the information provided, the state of the monopolar curved scissors is active, indicating that it is being used for a surgical procedure.
# ans: action done by monopolar curved scissors is idle
# pred: The bipolar forceps is located in the upper right-hand corner of the image.
# ans: bipolar forceps is located at left-bottom
# pred: The ProGrasp forceps are located on the right side of the image, just above the suture. They are a type of instrument used in laparoscopic surgery to grasp and manipulate tissues or organs inside the body.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located on the right side of the image, near the top. They are part of a surgical instrument set and are used for cutting and dissecting tissues during surgical procedures.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated is the stomach, as evidenced by the presence of the stomach staples and the surgical instruments in the image.
# ans: organ being operated is kidney
# pred: The image shows a laparoscope, which is a small camera that allows the surgeon to see inside the abdomen during surgery. The laparoscope is connected to a monitor that displays the images of the internal organs on a screen, allowing the surgeon to visualize the area and perform the procedure.
#
# *Answer*: Laparoscope
# ans: the tools operating are prograsp forceps , monopolar curved scissors , suction
# pred: The state of the prograsp forceps is that it is being used to grasp and manipulate tissue in a surgical procedure, as shown in the image.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is that they are being used in a surgical procedure, as indicated by the presence of a laparoscope and other surgical instruments in the image.
# ans: action done by monopolar curved scissors is cauterization
# pred: The state of suction is a medical device used to remove fluid, blood, or other substances from a body cavity, such as the abdominal cavity, thoracic cavity, or surgical site. It is commonly used in surgical procedures to remove fluid, blood, or other substances that may accumulate in the body cavity. The suction device is typically connected to a suction pump or a vacuum source that creates negative pressure to draw the fluid or substance into the device. The suction device is often used in conjunction with other medical instruments, such as a laparoscope or endoscope, to visualize the area being treated and to remove the fluid or substance. The suction device is commonly used in various medical procedures, including laparoscopic surgery, thoracic surgery, and gynecologic surgery.
# ans: action done by suction is idle
# pred: The prograsp forceps is located in the upper right corner of the image, inside the abdomen.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located on the left side of the image, near the top. They are part of a surgical instrument set and are used for making incisions in the tissue. The curved shape of the scissors allows for precise dissection and cutting of tissues in hard-to-reach areas.
# ans: monopolar curved scissors is located at right-top
# pred: The suction is located on the left side of the image, near the top. It is a long, thin, white tube with a rounded tip.
# ans: suction is located at right-top
# pred: The organ being operated on appears to be the kidney, as indicated by the presence of a kidney-shaped structure and the surgical instruments and sutures visible in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including a scalpel, forceps, and a suction irrigator, which are used to perform a surgical procedure on the organ.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The image depicts a surgical procedure, specifically a laparoscopic surgery, where the bipolar forceps are being used to grasp and manipulate tissues or organs inside the abdominal cavity. The forceps are held by the surgeon's right hand, with the tips of the forceps visible in the image.
#
# *Answer*: The bipolar forceps are in an open position.
# ans: action done by bipolar forceps is idle
# pred: The ProGrasp forceps are in a state of tension, as indicated by the visible stretching of the white plastic components and the black wires. This suggests that they are being used to grasp and manipulate the tissue or organ, likely for surgical purposes.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors is that they are being used to cut through a ligamentum teres, which is a strong fibrous cord that connects the left ventricle to the apex of the heart.
# ans: action done by monopolar curved scissors is cauterization
# pred: Bipolar forceps are typically located in the operating room, where they are used by surgeons to grasp and manipulate tissue during surgical procedures.
# ans: bipolar forceps is located at left-top
# pred: The ProGrasp forceps are located in the abdominal cavity, specifically in the pelvis.
# ans: prograsp forceps is located at left-top

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred, references=all_ans)
print(rouge_results)
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=1e57c1559c08b0e2a60a06e0ecb35de95d629a23ee0a87ba65a739ae036018c0
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.23525744557937478, 'rouge2': 0.12891666018102244, 'rougeL': 0.22710143260564986, 'rougeLsum': 0.22655250952061534}

# %%
bleu_score = corpus_bleu(all_ans, all_pred, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.05891303254363462
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans, all_pred):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0.32797577419719626
