# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasDhake/ColabNotebooks/blob/main/Reduced_Data_LAMA_Zero_Shot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install "torch==2.4.0" tensorboard pillow torchvision accelerate huggingface_hub
# !pip -q install  --upgrade \
  "transformers==4.45.1" \
  "datasets==3.0.1" \
  "accelerate==0.34.2" \
  "evaluate==0.4.3" \
  "bitsandbytes==0.44.0" \
  "trl==0.11.1" \
  "peft==0.13.0" \
  "qwen_vl_utils"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.3/797.3 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 77.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.6.1 which is incompatible.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.4.0 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['HF_HOME'] = '/home/sa5u24/VQA'
hf_home = os.path.expanduser(
    os.getenv("HF_HOME", os.path.join(os.getenv("XDG_CACHE_HOME", "~/.cache"), "huggingface"))
)
print(hf_home)

from huggingface_hub import login

# Replace 'your-hf-token-here' with your actual Hugging Face token
login(token="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")
# Out:
# /home/sa5u24/VQA

# %%
#Download code
# !git clone https://github.com/HRL-Mike/PitVQA.git

#Download Dataset
# !mkdir /content/PitVQA/datasets
# %cd /content/PitVQA/datasets
# !gdown --id 1FoAEY_u0PTAlrscjEifi2om15A83wL78

# Unzipping the VQA EndoVis18 Dataset
# !unzip -q EndoVis-18-VQA.zip
# %cd /content/PitVQA
# Out:
# Cloning into 'PitVQA'...
# remote: Enumerating objects: 401, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 401 (delta 74), reused 0 (delta 0), pack-reused 262 (from 1)
# Receiving objects: 100% (401/401), 14.44 MiB | 17.18 MiB/s, done.
# Resolving deltas: 100% (199/199), done.
# /content/PitVQA/datasets
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1FoAEY_u0PTAlrscjEifi2om15A83wL78
# From (redirected): https://drive.google.com/uc?id=1FoAEY_u0PTAlrscjEifi2om15A83wL78&confirm=t&uuid=80dbc12b-f39e-44dc-a834-0c6b56e9ab20
# To: /content/PitVQA/datasets/EndoVis-18-VQA.zip
# 100% 2.71G/2.71G [00:26<00:00, 101MB/s]
# /content/PitVQA

# %%
import os
import glob

from PIL import Image # Python Imaging Libary for image processing
from torch.utils.data import Dataset # Used to create custom datasets
import torchvision.transforms as transforms # Imports transomfrations to images
from torch.utils.data import DataLoader # helps to easily load batches of data from dataset
from pathlib import Path
from torchvision.transforms.functional import InterpolationMode # type of method used to resize images

class EndoVis18VQAGPTGen(Dataset):
    def __init__(self, seq, folder_head, folder_tail):
# seq = list of sequence numbers of identifiers, folder head and tail is the start and end of folder path
        self.transform = transforms.Compose([
            transforms.Resize((224, 224), interpolation=InterpolationMode.BICUBIC),  # input image size
            #transforms.ToTensor(),
        ])
# Resizing images to 224x224 using bicubic interpolation and they are made as tensors for the model
        # files, question and answers
        # Appens filenames to match the structure
        filenames = []
        for curr_seq in seq:
            filenames = filenames + glob.glob(folder_head + str(curr_seq) + folder_tail)
        self.vqas = []
        for file in filenames:
            file_data = open(file, "r")
            lines = [line.strip("\n") for line in file_data if line != "\n"]
            file_data.close()
            for line in lines:
                self.vqas.append([file, line])
        print('Total files: %d | Total question: %.d' % (len(filenames), len(self.vqas)))

        # List of predifined labels
        self.labels = ['kidney',
                'Idle', 'Grasping', 'Retraction', 'Tissue_Manipulation',
                'Tool_Manipulation', 'Cutting', 'Cauterization', 'Suction',
                'Looping', 'Suturing', 'Clipping', 'Staple', 'Ultrasound_Sensing',
                'left-top', 'right-top', 'left-bottom', 'right-bottom']

# Returns total number of samples in the dataset
    def __len__(self):
        return len(self.vqas)

# retrieves a specific dataset item by index idx
    def __getitem__(self, idx):
        qa_full_path = Path(self.vqas[idx][0])
        seq_path = qa_full_path.parents[2] # Gets grandparent directory two levels up of file path
        file_name = self.vqas[idx][0].split('/')[-1]  # / in linux and \\ in windows

        # img
        # Constructs path to the iamge file and joints the image with base name of the question file
        img_loc = os.path.join(seq_path, 'left_fr', file_name.split('_')[0] + '.png')
        raw_image = Image.open(img_loc).convert('RGB')
        img = self.transform(raw_image) # Applies transformation to the image (resizing and tensor conversion)

        # question and answer
        question, answer = self.vqas[idx][1].split('|') # splits qeustion and answer with |

        return img_loc, img, question, answer

# %%
system_message = """You are a Vision Language Model specialized in interpreting visual data from chart images.
Your task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.
The charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.
Focus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary."""

def format_data(sample):
    return [
        # {
        #     "role": "system",
        #     "content": [
        #         {
        #             "type": "text",
        #             "text": system_message
        #         }
        #     ],
        # },
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "image": sample[1],
                },
                {
                    "type": "text",
                    "text": sample[2],
                }
            ],
        },
        {
            "role": "assistant",
            "content": [
                {
                    "type": "text",
                    "text": sample[3]
                }
            ],
        },
    ]

# %%
class Args:
    def __init__(self):
        self.epochs = 20
        self.batch_size = 1

        self.random_seed = 42
        self.seq_length = 32
        self.lr = 0.00002

        self.vector_rank = [14, 14, 12, 12, 10, 10, 8, 8, 8, 8, 8, 8]
        self.lora_alpha = 32
        self.lora_dropout = 0.1


args = Args()
from torch.utils.data import DataLoader
#val_seq = [1, 5, 16]
val_seq = [1]
folder_head = '/content/PitVQA/datasets/EndoVis-18-VQA/seq_'
folder_tail = '/vqa/Sentence/*.txt'
PitVis_dataset = EndoVis18VQAGPTGen(val_seq, folder_head, folder_tail)
PitVis_data = [format_data(sample) for sample in PitVis_dataset]
# Out:
# Total files: 149 | Total question: 1164

# %%
for idx, sample in enumerate(PitVis_data):
    print(f"Sample {idx}: {sample}")
    if idx == 0:  # Check only a few samples
        break

# for idx, sample in enumerate(PitVis_data):
#     print("Sample:", sample)
#     if idx == 0:
#         break

test_data = sample
# Out:
# Sample 0: [{'role': 'user', 'content': [{'type': 'image', 'image': <PIL.Image.Image image mode=RGB size=224x224 at 0x791246878E90>}, {'type': 'text', 'text': 'what organ is being operated?'}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'organ being operated is kidney'}]}]

# %%
import gc
import time
from torchvision.transforms import ToPILImage


def clear_memory():
    # Delete variables if they exist in the current global scope
    if 'inputs' in globals(): del globals()['inputs']
    if 'model' in globals(): del globals()['model']
    if 'processor' in globals(): del globals()['processor']
    if 'trainer' in globals(): del globals()['trainer']
    if 'peft_model' in globals(): del globals()['peft_model']
    if 'bnb_config' in globals(): del globals()['bnb_config']
    time.sleep(2)

    # Garbage collection and clearing CUDA memory
    gc.collect()
    time.sleep(2)
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    time.sleep(2)
    gc.collect()
    time.sleep(2)

    print(f"GPU allocated memory: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
    print(f"GPU reserved memory: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")



def generate_text_from_sample(model, processor, sample, max_new_tokens=1024, device="cuda"):
    # Prepare the text input by applying the chat template
    text_input = processor.apply_chat_template(
        sample[:1],  # Use the sample without the system message
        tokenize=False,
        add_generation_prompt=True
    )

    # Process the visual input from the sample
    # image_inputs, _ = process_vision_info(sample)
    #image_inputs = sample[0].convert("RGB")
    image_inputs = sample[0]['content'][0]['image']
    #image_inputs = (sample[0].convert("RGB")).ToPILImage()
    # Prepare the inputs for the model
    model_inputs = processor(
        text=[text_input],
        images=image_inputs,
        return_tensors="pt",
    ).to(device)  # Move inputs to the specified device

    # Generate text with the model
    generated_ids = model.generate(**model_inputs, max_new_tokens=max_new_tokens)

    # Trim the generated ids to remove the input ids
    trimmed_generated_ids = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(model_inputs.input_ids, generated_ids)
    ]

    # Decode the output text
    output_text = processor.batch_decode(
        trimmed_generated_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return output_text[0]  # Return the first decoded output text

# %%
import torch
clear_memory()
# Out:
# GPU allocated memory: 0.00 GB
# GPU reserved memory: 0.00 GB

# %%
# !pip install -q evaluate

# %%
import evaluate
import torch
from nltk.translate.meteor_score import meteor_score, single_meteor_score
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
import requests
from torch import nn
from transformers import MllamaForConditionalGeneration, AutoProcessor, MllamaConfig, AutoModelForCausalLM
from typing import List, Optional, Tuple, Union
from PIL import Image
import matplotlib.pyplot as plt
from qwen_vl_utils import process_vision_info
from transformers import BitsAndBytesConfig



quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    # low_cpu_mem_usage=True,
    # bnb_4bit_compute_dtype=torch.float16
)

model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
processor = AutoProcessor.from_pretrained(model_id)
model = MllamaForConditionalGeneration.from_pretrained(
            model_id, torch_dtype=torch.bfloat16, device_map="auto", low_cpu_mem_usage=True,
            quantization_config=quantization_config,
        )

# with torch.no_grad():
#     for idx, sample in enumerate(PitVis_data):
#         outputs = generate_text_from_sample(model, processor, sample)
#         print("Outputs:", outputs)
#         if idx == 0:  # Test one batch
#             break

# all_pred = []
# all_ans = []
# model.eval()
# with torch.no_grad():
#     for sample in PitVis_data:
#         output = generate_text_from_sample(model, processor, sample)
#         ans = sample[1]['content'][0]['text']
#         all_pred.append(output)
#         all_ans.append(ans)

max_samples = 50
all_pred = []
all_ans = []
model.eval()
with torch.no_grad():
    for idx, sample in enumerate(PitVis_data):
        if idx >= max_samples:
            break
        output = generate_text_from_sample(model, processor, sample)
        ans = sample[1]['content'][0]['text']
        all_pred.append(output)
        all_ans.append(ans)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.8k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/5.09k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/89.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/1.47G [00:00<?, ?B/s]
# WARNING:accelerate.utils.modeling:The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
for i in range(len(all_pred)):
    print("pred:", all_pred[i])
    print("ans:", all_ans[i])
# Out:
# pred: The organ being operated on is the heart, as indicated by the surgical instruments and tools visible in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps and a heart retractor.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors , suction
# pred: The state of bipolar forceps is that they are being used to cauterize the heart, as indicated by their presence in the image.
# ans: action done by bipolar forceps is tissue manipulation
# pred: The prograsp forceps are in a state of being used to grasp and hold a heart during surgery, as shown in the image.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors in the image is that they are being used in a surgical procedure, likely for a cardiac surgery, as indicated by the presence of surgical instruments and the red color of the image, which suggests blood.
# ans: action done by monopolar curved scissors is cutting
# pred: The state of suction is a medical device used to remove air from a body cavity, such as the thoracic cavity, to help expand the lungs and improve breathing.
# ans: action done by suction is suction
# pred: The bipolar forceps is located in the middle of the image, where the instrument is being used to grasp and hold a specific object.
# ans: bipolar forceps is located at left-bottom
# pred: The prograsp forceps is located in the image, positioned above the heart.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors is located on the left side of the image, in the top portion of the image.
# ans: monopolar curved scissors is located at right-top
# pred: The suction is located at the bottom of the heart, as indicated by the clear plastic tubing attached to it.
# ans: suction is located at right-top
# pred: The organ being operated on is the heart, as evidenced by the presence of a heart tube and surgical instruments in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps and sutures.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are in an open position.
# ans: action done by bipolar forceps is idle
# pred: The state of the prograsp forceps is that it is being used to grasp and hold a gallbladder, as indicated by the presence of the forceps in the image.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors in the image is that they are being used to cut the tissue surrounding the tumor. The scissors are likely being used to make an incision around the tumor to remove it.
# ans: action done by monopolar curved scissors is cauterization
# pred: Bipolar forceps are a surgical instrument used to grasp and manipulate tissue, particularly in laparoscopic or endoscopic procedures. They are typically held in the surgeon's right hand, with the tips of the forceps positioned near the target area.
#
# **Step 1: Identify the location of the surgeon's right hand**
#
# The surgeon's right hand is the dominant hand used to perform the procedure.
#
# **Step 2: Determine the orientation of the forceps**
#
# Bipolar forceps are typically held with the tips pointing towards the target area.
#
# **Step 3: Locate the forceps in the surgeon's right hand**
#
# The forceps are held in the surgeon's right hand, with the tips positioned near the target area.
#
# **Answer:** The bipolar forceps are located in the surgeon's right hand, with the tips positioned near the target area.
# ans: bipolar forceps is located at left-bottom
# pred: ProGrasp forceps are a type of surgical instrument used in laparoscopic surgery. They are typically located in the surgeon's hand, specifically in the left hand, and are used to grasp and manipulate tissues during the procedure.
#
# In the image, the ProGrasp forceps are visible in the lower right corner of the image, with their tips extending into the abdominal cavity. They are attached to a black cord that runs from the forceps to a control unit outside the body, which allows the surgeon to manipulate the forceps remotely.
#
# The ProGrasp forceps are used to grasp and retract organs or tissues during the procedure, allowing the surgeon to access the area of interest and perform the necessary surgical procedures.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the upper right corner of the image, as indicated by the black instrument handle and the curved shape of the scissors.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated is the stomach, as indicated by the presence of the stomach wall and the suture line.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including a surgical retractor, a suction irrigator, and a suture.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: The state of bipolar forceps is a surgical instrument used to coagulate and cut tissue. The forceps are designed with two prongs that can be closed to grasp or hold tissue, and when the prongs are closed, an electrical current is passed through them to heat up and coagulate the tissue. This is particularly useful for procedures such as hemostasis, where bleeding needs to be controlled, or for cutting through tissue cleanly.
#
# *Answer*: Coagulation
# ans: action done by bipolar forceps is idle
# pred: The prograsp forceps is in an open position.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The instrument in the image is a monopolar curved scissors, which is a type of surgical instrument used for cutting and dissecting tissues. The curved shape of the scissors allows for precise cutting and dissection in tight spaces, making it ideal for procedures such as laparoscopic surgery.
#
# *Answer*: In the image, the monopolar curved scissors are in an open position, indicating that they are ready to be used to cut or dissect tissues.
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are typically located in the operating room, specifically in the hands of a surgeon or surgical assistant during a surgical procedure. They are used to grasp and manipulate tissues or organs during surgery, particularly in laparoscopic or endoscopic procedures.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are a type of surgical instrument used in minimally invasive procedures, such as laparoscopic surgery. They are typically located in the abdomen, specifically in the abdominal cavity, where they are used to grasp and manipulate tissues or organs during the procedure.
# ans: prograsp forceps is located at left-top
# pred: The monopolar curved scissors are located in the middle of the image, near the center of the abdominal cavity. They are positioned between the surgeon's hands, which are not visible in the image. The scissors are held by the surgeon's right hand, with the tips pointing towards the bottom of the image. The curved shape of the scissors suggests that they are designed for precise cutting and dissection tasks, such as making incisions or dissecting tissue.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on in the image is the heart. The image shows a close-up view of the heart, with sutures and surgical instruments visible, indicating that it is undergoing surgery.
# ans: organ being operated is kidney
# pred: The tools operating the organ are surgical instruments, including forceps, a needle, and sutures.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: **Step 1: Identify the instrument in the image.**
#
# The instrument in the image is a pair of bipolar forceps.
#
# **Step 2: Determine the state of the instrument.**
#
# The instrument is shown to be closed.
#
# **Step 3: Provide the final answer.**
#
# The state of the bipolar forceps is closed.
# ans: action done by bipolar forceps is idle
# pred: The prograsp forceps is in a closed position, as indicated by the tips being together and the jaws being shut.
# ans: action done by prograsp forceps is retraction
# pred: The state of the monopolar curved scissors is that it is being used in a surgical procedure, as indicated by the presence of surgical tools and instruments in the image. The scissors are likely being used to cut or dissect tissue, and the presence of the instrument suggests that the procedure is a surgical one.
# ans: action done by monopolar curved scissors is idle
# pred: Bipolar forceps are located in the upper right-hand corner of the image. They are a surgical instrument used to grasp and manipulate tissue during surgical procedures, and are typically held by the surgeon's left hand.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are located in the abdominal cavity, specifically in the peritoneal cavity, where they are used to grasp and manipulate tissues during surgical procedures.
# ans: prograsp forceps is located at left-bottom
# pred: The monopolar curved scissors are located in the abdominal cavity, as shown in the image.
# ans: monopolar curved scissors is located at right-bottom
# pred: The organ being operated on is the eye, as indicated by the presence of a metal clamp and sutures, which are commonly used in eye surgery.
# ans: organ being operated is kidney
# pred: The tools operating the organ are forceps, a scalpel, and a surgical needle with suture.
# ans: the tools operating are bipolar forceps , prograsp forceps
# pred: **Step 1: Identify the object in the image**
#
# The object in the image is a pair of forceps.
#
# **Step 2: Determine the state of the forceps**
#
# The forceps are closed.
#
# **Answer:** The state of the forceps is closed.
# ans: action done by bipolar forceps is idle
# pred: The ProGrasp forceps are in a closed position.
# ans: action done by prograsp forceps is retraction
# pred: Bipolar forceps are typically used in surgical procedures to grasp and hold tissue or organs during surgery, and are commonly found in the hands of surgeons. They are designed to apply electrical energy to the tissue, which can be used to cauterize or coagulate bleeding vessels, cut through tissue, or dissect and separate tissues.
#
# **Step 2: Identify the Purpose of the Forceps**
#
# Bipolar forceps are used to:
#
# * Apply electrical energy to tissue
# * Cauterize or coagulate bleeding vessels
# * Cut through tissue
# * Dissect and separate tissues
#
# **Step 3: Locate the Forceps**
#
# Given the context of the image, it is likely that the forceps are being used in a surgical procedure to apply electrical energy to the tissue.
#
# **Step 4: Answer**
#
# The bipolar forceps are located in the hands of the surgeon, who is using them to apply electrical energy to the tissue during a surgical procedure.
# ans: bipolar forceps is located at left-bottom
# pred: Prograsp forceps are a type of forceps used in surgical procedures, particularly in laparoscopic surgery. They are designed to grasp and manipulate tissues, such as organs or tissues inside the abdominal cavity, during minimally invasive surgical procedures.
#
# In the image provided, the Prograsp forceps are located in the upper part of the image, near the top. They are positioned in a way that suggests they are being used to grasp or manipulate a structure within the abdominal cavity. The forceps are likely being used to hold onto an organ or tissue to facilitate its manipulation or removal during a surgical procedure.
#
# It's important to note that the exact location of the Prograsp forceps can vary depending on the specific surgical procedure being performed and the surgeon's preference. However, in general, they are typically used in the upper part of the abdominal cavity to access and manipulate structures such as the liver, gallbladder, stomach, small intestine, and other organs.
#
# Overall, the Prograsp forceps play a crucial role in many laparoscopic surgical procedures, allowing surgeons to perform complex operations with greater precision and accuracy.
# ans: prograsp forceps is located at left-bottom
# pred: The organ being operated on is the stomach. The surgeon is using a laparoscope to visualize the interior of the stomach and perform the procedure.
# ans: organ being operated is kidney
# pred: The tools operating the organ are a laparoscope, a surgical retractor, and a suction irrigator.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors
# pred: Bipolar forceps are a type of surgical instrument used to grasp and manipulate tissue during surgical procedures. They are called "bipolar" because they have two prongs that can be opened and closed like scissors, but instead of cutting, they are used to grasp and hold onto tissue.
#
# The state of bipolar forceps can vary depending on their intended use and the specific application. Here are some common states of bipolar forceps:
#
# * **Open**: The prongs of the forceps are fully opened, allowing for a wide range of motion and easy access to the tissue.
# * **Closed**: The prongs are closed, providing a secure grip on the tissue.
# * **Semi-open**: The prongs are partially opened, allowing for a more precise grasp on the tissue.
# * **Semi-closed**: The prongs are partially closed, providing a gentle but firm grasp on the tissue.
# * **Tightened**: The prongs are closed and tightened, providing a secure and firm grasp on the tissue.
# * **Loosened**: The prongs are opened and loosened, allowing for easy release of the tissue.
#
# It's important to note that the state of the bipolar forceps will depend on the specific surgical procedure and the surgeon's preference. The forceps should be used with care and precision to avoid causing injury to the surrounding tissue or organs.
# ans: action done by bipolar forceps is idle
# pred: The prograsp forceps are in the state of being used to grasp and manipulate tissue, as indicated by the blood on them.
# ans: action done by prograsp forceps is tissue manipulation
# pred: The state of the monopolar curved scissors in the image is that it is being used to cut a blood vessel, as indicated by the presence of blood on the scissors and the surrounding area.
# ans: action done by monopolar curved scissors is cutting
# pred: Bipolar forceps are located in the abdominal cavity, specifically in the area where the surgeon is performing the surgery. The forceps are used to grasp and manipulate tissues and organs during the procedure.
#
# *Answer*: Abdomen
# ans: bipolar forceps is located at left-top
# pred: The prograsp forceps are located in the abdominal cavity, as indicated by the image. The forceps are part of a surgical procedure, and their presence suggests that they are being used to grasp or manipulate tissues or organs within the abdominal cavity.
# ans: prograsp forceps is located at left-top
# pred: The instrument in the image is a monopolar curved scissors, which is a surgical tool used for cutting and dissecting tissues. It is typically located in the right hand of the surgeon, with the curved part of the scissors facing towards the target area. The instrument is held at an angle to allow for precise cutting and dissection of tissues.
# ans: monopolar curved scissors is located at right-top
# pred: The organ being operated on is the stomach. The image shows a surgical procedure, likely a laparoscopic gastrectomy, where the stomach is being opened and manipulated by the instruments in the image.
# ans: organ being operated is kidney
# pred: The tools operating the organ are laparoscopic instruments, which are used for minimally invasive surgery. These instruments are inserted through small incisions in the abdominal wall and provide a clear view of the internal organs on a video monitor.
# ans: the tools operating are bipolar forceps , prograsp forceps , monopolar curved scissors , clip applier

# %%
# !pip install rouge_score
rouge = evaluate.load("rouge")
rouge_results = rouge.compute(predictions= all_pred, references=all_ans)
print(rouge_results)
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (4.67.1)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=c67fd5574db8bfa1ab5acc1da668f250c2950ce29533b57ac2fe2c555ab9a89b
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.22290876583578179, 'rouge2': 0.11798977365829522, 'rougeL': 0.21348433850195775, 'rougeLsum': 0.21319395272708408}

# %%
bleu_score = corpus_bleu(all_ans, all_pred, weights=(1.0, 0.0, 0.0, 0.0))
print(bleu_score)
# Out:
# 0.06316608323609489
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.11/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
import nltk
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

m_score=0
for line in zip(all_ans, all_pred):
    ref = word_tokenize(line[0])
    hypo = word_tokenize(line[1])
    m_score += meteor_score([ref], hypo)
meteors = m_score/len(all_ans)
print(meteors)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# 0.31104378064449073
